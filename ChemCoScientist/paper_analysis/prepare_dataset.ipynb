# %%
import pandas as pd

# %%
df = pd.read_csv('questions_dataset_0.2.csv')
df.head()
# Out:
#    Номер вопроса                                         paper_name  \
# 0              1                  koning-et-al-2021-total-synthesis
# 1              2                            10_1021_acs_joc_0c02350
# 2              3                                       d1ra01912k-2
# 3              4                                       d1ra01912k-2
# 4              5  Die Angewandte Makromolekulare Chemie - 1999 -...
#
#    Уровень сложности  Необходмый раздел для ответа  \
# 0                NaN                           NaN
# 1                NaN                           NaN
# 2                NaN                           NaN
# 3                NaN                           NaN
# 4                NaN                           NaN
#
#    Необходмый текст для ответа (страница)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    Необходмый рисунок для ответа (номер)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Необходмая таблица для ответа (номер)  Unnamed: 7  \
# 0                                    NaN         NaN
# 1                                    NaN         NaN
# 2                                    NaN         NaN
# 3                                    NaN         NaN
# 4                                    NaN         NaN
#
#                                             question  Тег  Тип ответа  \
# 0  What reaction occurs in step 6 of Total Synthe...  NaN         NaN
# 1  I need all the compounds that were used in the...  NaN         NaN
# 2                                                NaN  NaN         NaN
# 3                                                NaN  NaN         NaN
# 4                   What is happening in diagram 5 ?  NaN         NaN
#
#                                                Ответ  \
# 0  In step 6 of Total Synthesis of (-)-Glionitrin...
# 1  Lithium bromide\n[Li+].[Br-]  \nN,N-dimethylac...
# 2                                                NaN
# 3                                                NaN
# 4  The diagram shows the reaction between one mol...
#
#                                  chroma_text_context  chroma_images_context  \
# 0  What reaction occurs in step 6 of Total Synthe...                    NaN
# 1  I need all the compounds that were used in the...                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                   What is happening in diagram 5 ?                    NaN
#
#    llm_answer
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.rename(columns={"paper_name":"pdf", "Ответ":"answer"}, inplace=True)

# %%
data = df.copy()

# %%
data = data[['pdf', 'question', 'answer']]

# %%
data.head()
# Out:
#                                                  pdf  \
# 0                  koning-et-al-2021-total-synthesis
# 1                            10_1021_acs_joc_0c02350
# 2                                       d1ra01912k-2
# 3                                       d1ra01912k-2
# 4  Die Angewandte Makromolekulare Chemie - 1999 -...
#
#                                             question  \
# 0  What reaction occurs in step 6 of Total Synthe...
# 1  I need all the compounds that were used in the...
# 2                                                NaN
# 3                                                NaN
# 4                   What is happening in diagram 5 ?
#
#                                               answer
# 0  In step 6 of Total Synthesis of (-)-Glionitrin...
# 1  Lithium bromide\n[Li+].[Br-]  \nN,N-dimethylac...
# 2                                                NaN
# 3                                                NaN
# 4  The diagram shows the reaction between one mol...

# %%
data = data[data.question.isna()==False]
data.head()
# Out:
#                                                  pdf  \
# 0                  koning-et-al-2021-total-synthesis
# 1                            10_1021_acs_joc_0c02350
# 4  Die Angewandte Makromolekulare Chemie - 1999 -...
# 5  Die Angewandte Makromolekulare Chemie - 1999 -...
# 6  hernandez-et-al-2023-alkynyl-halo-aza-prins-an...
#
#                                             question  \
# 0  What reaction occurs in step 6 of Total Synthe...
# 1  I need all the compounds that were used in the...
# 4                   What is happening in diagram 5 ?
# 5  Are there any compounds for which IR was taken...
# 6                    What is happening in Scheme 2 ?
#
#                                               answer
# 0  In step 6 of Total Synthesis of (-)-Glionitrin...
# 1  Lithium bromide\n[Li+].[Br-]  \nN,N-dimethylac...
# 4  The diagram shows the reaction between one mol...
# 5       yes, these are compounds 1a, 1b, 1c, 1d, 1f.
# 6  The scheme shows the reaction between one mole...

# %%
data = data[data.pdf!='molecules-28-02420-v2.pdf']
data.shape
# Out:
# (18, 3)

# %%
data
# Out:
#                                                   pdf  \
# 0                   koning-et-al-2021-total-synthesis
# 1                             10_1021_acs_joc_0c02350
# 4   Die Angewandte Makromolekulare Chemie - 1999 -...
# 5   Die Angewandte Makromolekulare Chemie - 1999 -...
# 6   hernandez-et-al-2023-alkynyl-halo-aza-prins-an...
# 7   kowalska-et-al-2023-visible-light-promoted-3-2...
# 8   kowalska-et-al-2023-visible-light-promoted-3-2...
# 9   kowalska-et-al-2023-visible-light-promoted-3-2...
# 10  kowalska-et-al-2023-visible-light-promoted-3-2...
# 11  kowalska-et-al-2023-visible-light-promoted-3-2...
# 12  kowalska-et-al-2023-visible-light-promoted-3-2...
# 13  kowalska-et-al-2023-visible-light-promoted-3-2...
# 14  hernandez-et-al-2023-alkynyl-halo-aza-prins-an...
# 15  hernandez-et-al-2023-alkynyl-halo-aza-prins-an...
# 16  hernandez-et-al-2023-alkynyl-halo-aza-prins-an...
# 17  hernandez-et-al-2023-alkynyl-halo-aza-prins-an...
# 18                                       d1ra01912k-2
# 19                                       d1ra01912k-2
#
#                                              question  \
# 0   What reaction occurs in step 6 of Total Synthe...
# 1   I need all the compounds that were used in the...
# 4                    What is happening in diagram 5 ?
# 5   Are there any compounds for which IR was taken...
# 6                     What is happening in Scheme 2 ?
# 7   How many chiral centers are there in the compo...
# 8   Which photocatalyst showed the best results in...
# 9   Which biologically active compounds are shown ...
# 10  In which solvent did the reaction of [3+2]-cyc...
# 11  What was the diastereomer ratio for product 3a...
# 12  Name the compounds that reacted [3+2]-cyclopro...
# 13  What is the IUPAC nomenclature name and the mo...
# 14          What is the name of substance number 24a?
# 15    Why was the yield for 16t greater than for 16b?
# 16    Calculate the molecular weight for compound 19q
# 17  Which substituents cause the formation of E- a...
# 18  Which compound has the highest polymerization ...
# 19                What is rac-(3-Et Ind#)2Zr(CH2Ph)2?
#
#                                                answer
# 0   In step 6 of Total Synthesis of (-)-Glionitrin...
# 1   Lithium bromide\n[Li+].[Br-]  \nN,N-dimethylac...
# 4   The diagram shows the reaction between one mol...
# 5        yes, these are compounds 1a, 1b, 1c, 1d, 1f.
# 6   The scheme shows the reaction between one mole...
# 7                                                   3
# 8                                             Eosin Y
# 9   Diaportheone B, Applanatumol Y,Peramivir, Jatr...
# 10                                           Methanol
# 11                                            10:1 dr
# 12                                1ba, 1c, 1g, 1h, 1i
# 13  (2,2,6,6-tetramethylpiperidin-1-yl)oxidanyl , ...
# 14  3-benzhydrylidene-1-(4-methylphenyl)sulfonyl-2...
# 15  Since at the last step, alkynyl Prints cycliza...
# 16                                            332.241
# 17  The MeO group in the para position and the Me ...
# 18  There is no compound that has the highest poly...
# 19  rac-(3-EtInd#)2Zr(CH2Ph)2 is a zirconocene com...

# %%
data.pdf = data['pdf'].apply(lambda x: x+'.pdf' if x.endswith('pdf')==False else x)

# %%
data.head()
# Out:
#                                                  pdf  \
# 0              koning-et-al-2021-total-synthesis.pdf
# 1                        10_1021_acs_joc_0c02350.pdf
# 4  Die Angewandte Makromolekulare Chemie - 1999 -...
# 5  Die Angewandte Makromolekulare Chemie - 1999 -...
# 6  hernandez-et-al-2023-alkynyl-halo-aza-prins-an...
#
#                                             question  \
# 0  What reaction occurs in step 6 of Total Synthe...
# 1  I need all the compounds that were used in the...
# 4                   What is happening in diagram 5 ?
# 5  Are there any compounds for which IR was taken...
# 6                    What is happening in Scheme 2 ?
#
#                                               answer
# 0  In step 6 of Total Synthesis of (-)-Glionitrin...
# 1  Lithium bromide\n[Li+].[Br-]  \nN,N-dimethylac...
# 4  The diagram shows the reaction between one mol...
# 5       yes, these are compounds 1a, 1b, 1c, 1d, 1f.
# 6  The scheme shows the reaction between one mole...

# %%
data.pdf.unique()
# Out:
# array(['koning-et-al-2021-total-synthesis.pdf',
#        '10_1021_acs_joc_0c02350.pdf',
#        'Die Angewandte Makromolekulare Chemie - 1999 - Moszner - Synthesis and polymerisation of new multifunctional urethane.pdf',
#        'hernandez-et-al-2023-alkynyl-halo-aza-prins-annulative-couplings.pdf',
#        'kowalska-et-al-2023-visible-light-promoted-3-2-cycloaddition-for-the-synthesis-of-cyclopenta-b-chromenocarbonitrile.pdf',
#        'd1ra01912k-2.pdf'], dtype=object)

# %%
data.to_csv('questions_dataset_0.2_prepared.csv', index=False)

# %%
df = pd.read_csv('test_results/gemini-2.0-flash-lite-001_v0.2.csv')
df.head()
# Out:
#                                                  pdf  \
# 0  ..\ChemCoScientist\paper_analysis\papers\konin...
# 1  ..\ChemCoScientist\paper_analysis\papers\10_10...
# 2  ..\ChemCoScientist\paper_analysis\papers\Die A...
# 3  ..\ChemCoScientist\paper_analysis\papers\Die A...
# 4  ..\ChemCoScientist\paper_analysis\papers\herna...
#
#                                             question  \
# 0  What reaction occurs in step 6 of Total Synthe...
# 1  I need all the compounds that were used in the...
# 2                   What is happening in diagram 5 ?
# 3  Are there any compounds for which IR was taken...
# 4                    What is happening in Scheme 2 ?
#
#                                       correct_answer  \
# 0  In step 6 of Total Synthesis of (-)-Glionitrin...
# 1  Lithium bromide\n[Li+].[Br-]  \nN,N-dimethylac...
# 2  The diagram shows the reaction between one mol...
# 3       yes, these are compounds 1a, 1b, 1c, 1d, 1f.
# 4  The scheme shows the reaction between one mole...
#
#                                         model_answer  \
# 0  In step 6 of Total Synthesis of (-)-Glionitrin...
# 1  I am sorry, but I cannot fulfill this request....
# 2  In diagram 5, benzyl $\alpha$-hydroxymethylacr...
# 3  Yes, the IR spectra were recorded for the foll...
# 4  In Scheme 2, primary homoallylic amines 12 rea...
#
#    Correctness (GEval)_score  \
# 0                        0.7
# 1                        0.2
# 2                        0.6
# 3                        0.8
# 4                        0.3
#
#                           Correctness (GEval)_reason
# 0  All essential information about dihydroxylatio...
# 1  Actual output states it cannot fulfill the req...
# 2  The actual output captures the essential infor...
# 3  The actual output correctly identifies compoun...
# 4  The actual output mentions Scheme 2 involving ...

# %%
df['Correctness (GEval)_score'].mean()
# Out:
# np.float64(0.30000000000000004)

# %%
df_0 = df[df['Correctness (GEval)_score']!=1.0]
df_0
# Out:
#                                                   pdf  \
# 0   ..\ChemCoScientist\paper_analysis\papers\konin...
# 1   ..\ChemCoScientist\paper_analysis\papers\10_10...
# 2   ..\ChemCoScientist\paper_analysis\papers\Die A...
# 3   ..\ChemCoScientist\paper_analysis\papers\Die A...
# 4   ..\ChemCoScientist\paper_analysis\papers\herna...
# 5   ..\ChemCoScientist\paper_analysis\papers\kowal...
# 6   ..\ChemCoScientist\paper_analysis\papers\kowal...
# 8   ..\ChemCoScientist\paper_analysis\papers\kowal...
# 10  ..\ChemCoScientist\paper_analysis\papers\kowal...
# 11  ..\ChemCoScientist\paper_analysis\papers\kowal...
# 12  ..\ChemCoScientist\paper_analysis\papers\herna...
# 13  ..\ChemCoScientist\paper_analysis\papers\herna...
# 14  ..\ChemCoScientist\paper_analysis\papers\herna...
# 15  ..\ChemCoScientist\paper_analysis\papers\herna...
# 16  ..\ChemCoScientist\paper_analysis\papers\d1ra0...
# 17  ..\ChemCoScientist\paper_analysis\papers\d1ra0...
#
#                                              question  \
# 0   What reaction occurs in step 6 of Total Synthe...
# 1   I need all the compounds that were used in the...
# 2                    What is happening in diagram 5 ?
# 3   Are there any compounds for which IR was taken...
# 4                     What is happening in Scheme 2 ?
# 5   How many chiral centers are there in the compo...
# 6   Which photocatalyst showed the best results in...
# 8   In which solvent did the reaction of [3+2]-cyc...
# 10  Name the compounds that reacted [3+2]-cyclopro...
# 11  What is the IUPAC nomenclature name and the mo...
# 12          What is the name of substance number 24a?
# 13    Why was the yield for 16t greater than for 16b?
# 14    Calculate the molecular weight for compound 19q
# 15  Which substituents cause the formation of E- a...
# 16  Which compound has the highest polymerization ...
# 17                What is rac-(3-Et Ind#)2Zr(CH2Ph)2?
#
#                                        correct_answer  \
# 0   In step 6 of Total Synthesis of (-)-Glionitrin...
# 1   Lithium bromide\n[Li+].[Br-]  \nN,N-dimethylac...
# 2   The diagram shows the reaction between one mol...
# 3        yes, these are compounds 1a, 1b, 1c, 1d, 1f.
# 4   The scheme shows the reaction between one mole...
# 5                                                   3
# 6                                             Eosin Y
# 8                                            Methanol
# 10                                1ba, 1c, 1g, 1h, 1i
# 11  (2,2,6,6-tetramethylpiperidin-1-yl)oxidanyl , ...
# 12  3-benzhydrylidene-1-(4-methylphenyl)sulfonyl-2...
# 13  Since at the last step, alkynyl Prints cycliza...
# 14                                            332.241
# 15  The MeO group in the para position and the Me ...
# 16  There is no compound that has the highest poly...
# 17  rac-(3-EtInd#)2Zr(CH2Ph)2 is a zirconocene com...
#
#                                          model_answer  \
# 0   In step 6 of Total Synthesis of (-)-Glionitrin...
# 1   I am sorry, but I cannot fulfill this request....
# 2   In diagram 5, benzyl $\alpha$-hydroxymethylacr...
# 3   Yes, the IR spectra were recorded for the foll...
# 4   In Scheme 2, primary homoallylic amines 12 rea...
# 5   There are 2 chiral centers in the compound 3af.\n
# 6   I am sorry, but I cannot answer the question. ...
# 8   The reactions between 3-Cyanochromone 1a and N...
# 10  The compounds that reacted with N-cyclopropyla...
# 11  I am sorry, but I am unable to answer your que...
# 12  The name of substance 24a is:  a functionalize...
# 13  I am sorry, but the provided document does not...
# 14  I am sorry, but I am unable to answer your que...
# 15  I am sorry, but the provided document does not...
# 16  *   Over the entire temperature range, the com...
# 17  rac-(3-Et Ind)2Zr(CH2Ph)2, is a yellow solid. ...
#
#     Correctness (GEval)_score  \
# 0                         0.7
# 1                         0.2
# 2                         0.6
# 3                         0.8
# 4                         0.3
# 5                         0.0
# 6                         0.0
# 8                         0.2
# 10                        0.0
# 11                        0.0
# 12                        0.0
# 13                        0.0
# 14                        0.0
# 15                        0.0
# 16                        0.4
# 17                        0.2
#
#                            Correctness (GEval)_reason
# 0   All essential information about dihydroxylatio...
# 1   Actual output states it cannot fulfill the req...
# 2   The actual output captures the essential infor...
# 3   The actual output correctly identifies compoun...
# 4   The actual output mentions Scheme 2 involving ...
# 5   The numeric value in the actual output, 2, doe...
# 6   The actual output fails to identify that Eosin...
# 8   The actual output references the lowest yield ...
# 10  The actual output lists compounds (3ba and 3ca...
# 11  The actual output lacks any essential informat...
# 12  The actual output provides a different chemica...
# 13  The actual output does not contain any essenti...
# 14  The actual output does not provide the essenti...
# 15  The actual output completely lacks the specifi...
# 16  The actual output correctly identifies meso-5s...
# 17  The actual output mentions the chemical as a y...

# %%
for i, row in df_0.iterrows():
    print('-----------------------')
    print(row['pdf'])
    print(row['question'])
    print(row['correct_answer'])
    print(row['model_answer'])
# Out:
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\koning-et-al-2021-total-synthesis.pdf
# What reaction occurs in step 6 of Total Synthesis of (-)-Glionitrin A/B? What reagents were involved in the reaction and what product was obtained? What was the yield obtained?
# In step 6 of Total Synthesis of (-)-Glionitrin A/B, a double bond hydroxylation reaction (R)-10a-((((R)-1-(4-Methoxyphenyl)ethyl)thio)-2-methyl-3-methylene-7-nitro-2,3,10,10,10a-tetrahydropyrazino[1,2-a]indole-1,4-dione (in article and SI number 32) occurred to give (3S, 10aR)-3-Hydroxy-3-(hydroxymethyl)-10a-(((R)-1- (4-methoxyphenyl)ethyl)thio)-2-methyl-7-nitro-2,3,10,10,10a-tetrahydropyrazino[1,2-a]indole-1,4-dione (trans isomer, in article number 33, in SI as trans-33) and (3R,10aR)-3-hydroxy-3-(hydroxymethyl)-10a-[(1R)-1-(4-methoxyphenyl)ethyl]sulfanyl-2-methyl-7-nitro-10H-pyrazino[1,2-a]indole-1,4-dione (cis-isomer, in SI as cis-33). The reaction was carried out with 0.1 equiv OsO4 dissolved in 2.5% tert-BuOH, 2.0 equiv NMO, 75:25 acetone and water, respectively, for 16 hours. The yield was 85 percent with a ratio of trans and cis diastereomers 87:13 respectively.
# In step 6 of Total Synthesis of (-)-Glionitrin A/B, dihydroxylation occurred. The reagents involved were OsO4 (0.1 equiv, 2.5% (w/w) in tert-BuOH), NMO (2.0 equiv), acetone/H2O. The product obtained was 33. The yield obtained was 85%.
#
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\10_1021_acs_joc_0c02350.pdf
# I need all the compounds that were used in the experiments. Obligatorily I need all results to be in the form of a table of 2 columns where in the first column were the names by IUPAC nomenclature and in the second column in SMILES notation. Don't add it to this list of reaction products for me. Would you be able to do that?
# Lithium bromide
# [Li+].[Br-]
# N,N-dimethylacetamide
# CC(=O)N(C)C
# 2-[2-[bis(carboxylatomethyl)azaniumyl]ethyl-(carboxylatomethyl)azaniumyl]acetate  disodium
# C(C[NH+](CC(=O)[O-])CC(=O)[O-])[NH+](CC(=O)[O-])CC(=O)[O-].[Na+].[Na+]
# carbonate  dipotassium
# C(=O)([O-])[O-].[K+].[K+]
# pentane
# CCCCC
# ethoxyethane
# CCOCC
# sulfate disodium
# [O-]S(=O)(=O)[O-].[Na+].[Na+]
# sodium;chloride
#  [Na+].[Cl-]
# oxidane
# O
# 2-pyridin-2-ylpyridine
# C1=CC=NC(=C1)C2=CC=CC=N2
# argon
# [Ar]
# potassium;dihydrogen phosphate
# OP(=O)(O)[O-].[K+]
# hexane
# CCCCCC
# dichloromethane
# C(Cl)Cl
# N,N-dimethylformamide
# CN(C)C=O
# 1-azabicyclo[2.2.2]octane
# C1CN2CCC1CC2
# morpholine
# C1COCCN1
# 1-bromo-4-(trifluoromethyl)benzene
# C1=CC(=CC=C1C(F)(F)F)Br
# trichloro(deuterio)methane
# [2H]C(Cl)(Cl)Cl
# cyclohexanamine
# C1CCC(CC1)N
# hexan-1-amine
# CCCCCCN
#  N-methylmethanamine;hydrochloride
# CNC.Cl
# methyl 2-aminoacetate;hydrochloride
#  COC(=O)CN.Cl
# bromobenzene
# C1=CC=C(C=C1)Br
# 4-bromobenzonitrile
# C1=CC(=CC=C1C#N)Br
# 4-bromobenzoate
#  C1=CC(=CC=C1C(=O)[O-])Br
# 2-bromonaphthalene
#  C1=CC=C2C=C(C=CC2=C1)Br
# 1-bromo-2-methylbenzene
# CC1=CC=CC=C1Br
# 3-bromopyridine
# C1=CC(=CN=C1)Br
# ethyl acetate
# CCOC(=O)C
# ethoxyethane
# CCOCC
# 1-bromo-3-methoxybenzene
# COC1=CC(=CC=C1)Br
# benzoic acid
# C1=CC=C(C=C1)C(=O)O
# (2S)-5-[(2-methylpropan-2-yl)oxy]-2-[(2-methylpropan-2-yl)oxycarbonylamino]-5-oxopentanoic acid
# CC(C)(C)OC(=O)CC[C@@H](C(=O)O)NC(=O)OC(C)(C)C
# dimethyl butanedioate
# COC(=O)CCC(=O)OC
# sodium;acetate
# CC(=O)[O-].[Na+]
# (2S)-1-[(2-methylpropan-2-yl)oxycarbonyl]pyrrolidine-2-carboxylic acid
# CC(C)(C)OC(=O)N1CCC[C@H]1C(=O)O
# phenylmethanol
# C1=CC=C(C=C1)CO
# cyclohexanol
#  C1CCC(CC1)O
# propan-2-ol
# CC(C)O
# hexan-1-ol
# CCCCCCO
# methyl 4-bromobenzoate
# COC(=O)C1=CC=C(C=C1)Br
# 3-bromopyridine
# C1=CC(=CN=C1)Br
# Acetonitrile
# CC#N
# 4-tert-butyl-2-(4-tert-butylpyridin-2-yl)pyridine
# CC(C)(C)C1=CC(=NC=C1)C2=NC=CC(=C2)C(C)(C)C
# tetrabutylazanium;hexafluorophosphate
# CCCC[N+](CCCC)(CCCC)CCCC.F[P-](F)(F)(F)(F)F
# I am sorry, but I cannot fulfill this request. The provided documents do not contain the SMILES notation of the compounds used in the described experiments. Therefore, I am unable to create the table as requested.
#
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\Die Angewandte Makromolekulare Chemie - 1999 - Moszner - Synthesis and polymerisation of new multifunctional urethane.pdf
# What is happening in diagram 5 ?
# The diagram shows the reaction between one molecule of TMXDI ( 1,3-bis(2-isocyanatopropan-2-yl)benzene ) and two molecules of ( benzyl 2-(hydroxymethyl)prop-2-enoate ) in the presence of DBTDO ( dibutyltin dioctanoate ) and the release of 2 molecules of CO2 (carbon dioxide, carbon dioxide) and one molecule of benzyl 2-[[2-[[2-[3-[2-[2-(2-phenylmethoxycarbonylprop-2-enylamino)propan-2-yl]phenyl]propan-2-ylamino]methyl]prop-2-enoate
# In diagram 5, benzyl $\alpha$-hydroxymethylacrylate reacts with TMXDI (tetramethyl-m-xylylene diisocyanate) in the presence of DBTDO (dibutyltin dioctanoate) as catalyst, resulting in the formation of a bifunctional amine methacrylate with the elimination of carbon dioxide.
#
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\Die Angewandte Makromolekulare Chemie - 1999 - Moszner - Synthesis and polymerisation of new multifunctional urethane.pdf
# Are there any compounds for which IR was taken? If there are, write me the abbreviations of those compounds that were taken in pure form.
# yes, these are compounds 1a, 1b, 1c, 1d, 1f.
# Yes, the IR spectra were recorded for the following compounds in the neat (pure) form: 1a, 1b, 1c, and 1f.
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\hernandez-et-al-2023-alkynyl-halo-aza-prins-annulative-couplings.pdf
# What is happening in Scheme 2 ?
# The scheme shows the reaction between one molecule of 3-Buten-1-amine and one molecule of Methyl (2-formylphenyl)carbamate to form (10R)-10-acetyl-5,8,9,9,10,11,11a-hexahydropyrido[1,2-c]quinazolin-6-one. The reaction takes place in the presence of acetic acid at 160 ℃
# In Scheme 2, primary homoallylic amines 12 react with benzaldehyde derivatives 13 to produce 2-quinazolinones 14. This reaction is promoted by the use of acetic acid (AcOH) at 140 °C.
#
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\kowalska-et-al-2023-visible-light-promoted-3-2-cycloaddition-for-the-synthesis-of-cyclopenta-b-chromenocarbonitrile.pdf
# How many chiral centers are there in the compound 3af ?
# 3
# There are 2 chiral centers in the compound 3af.
#
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\kowalska-et-al-2023-visible-light-promoted-3-2-cycloaddition-for-the-synthesis-of-cyclopenta-b-chromenocarbonitrile.pdf
# Which photocatalyst showed the best results in the reaction of [3+2]-cycloaddition of 3-Cyanochromone 1a and N-Cyclopropyloaniline 2a in dichloromethane?
# Eosin Y
# I am sorry, but I cannot answer the question. There is no mention of the reaction of [3+2]-cycloaddition of 3-Cyanochromone 1a and N-Cyclopropyloaniline 2a in dichloromethane in the provided text.
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\kowalska-et-al-2023-visible-light-promoted-3-2-cycloaddition-for-the-synthesis-of-cyclopenta-b-chromenocarbonitrile.pdf
# In which solvent did the reaction of [3+2]-cycloaddition of 3-Cyanochromone 1a and N-Cyclopropyloaniline 2a produce the lowest yield?
# Methanol
# The reactions between 3-Cyanochromone 1a and N-Cyclopropyloaniline 2a were performed in different solvents. The lowest yield, with the blue light irradiation, was observed when the reaction was performed in $\mathrm{CH}_{2} \mathrm{Cl}_{2}$, with 57% yield (Table 1, entry 4).
#
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\kowalska-et-al-2023-visible-light-promoted-3-2-cycloaddition-for-the-synthesis-of-cyclopenta-b-chromenocarbonitrile.pdf
# Name the compounds that reacted [3+2]-cyclopropyl compounds with N-cyclopropylaniline 2a, with an electron-donor group, which were varied to study the effect of substituents
# 1ba, 1c, 1g, 1h, 1i
# The compounds that reacted with N-cyclopropylaniline 2a, with an electron-donor group, which were varied to study the effect of substituents are 6-methoxy-9-oxo-1-(phenylamino)-1,2,3,3a,9,9a-hexahydrocyclopenta[b]chromene-9a-carbonitrile (3ba) and 7-methoxy-9-oxo-1-(phenylamino)-1,2,3,3a,9,9a-hexahydrocyclopenta[b]chromene-9a-carbonitrile (3ca).
#
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\kowalska-et-al-2023-visible-light-promoted-3-2-cycloaddition-for-the-synthesis-of-cyclopenta-b-chromenocarbonitrile.pdf
# What is the IUPAC nomenclature name and the molecular weight of TEMPO?
# (2,2,6,6-tetramethylpiperidin-1-yl)oxidanyl , 156.25 g/mol
# I am sorry, but I am unable to answer your question. The provided document does not contain the IUPAC nomenclature name or molecular weight of TEMPO.
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\hernandez-et-al-2023-alkynyl-halo-aza-prins-annulative-couplings.pdf
# What is the name of substance number 24a?
# 3-benzhydrylidene-1-(4-methylphenyl)sulfonyl-2-propan-2-ylpiperidine
# The name of substance 24a is:  a functionalized tosyl-piperidine.
#
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\hernandez-et-al-2023-alkynyl-halo-aza-prins-annulative-couplings.pdf
# Why was the yield for 16t greater than for 16b?
# Since at the last step, alkynyl Prints cyclization occurs, in which the nucleophile participates in the form of a Halogenide.The yield of 16e in this reaction will be higher due to the presence of iodide, which is more nucleophilic than bromine.
# I am sorry, but the provided document does not contain information about compound 16t. Therefore, I am unable to answer your question.
#
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\hernandez-et-al-2023-alkynyl-halo-aza-prins-annulative-couplings.pdf
# Calculate the molecular weight for compound 19q
# 332.241
# I am sorry, but I am unable to answer your question. The molecular formula for compound 19q is not provided in the text you provided.
#
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\hernandez-et-al-2023-alkynyl-halo-aza-prins-annulative-couplings.pdf
# Which substituents cause the formation of E- and Z-isomers in the Alkynyl Aza-Prince Cyclization of Phthalimido Arenyne Hemiaminals reaction, i.e. systems that have unusual interference or release electrons?
# The MeO group in the para position and the Me group in the ortho position
# I am sorry, but the provided document does not contain information about the substituents which are responsible for the formation of E- and Z-isomers in the Alkynyl Aza-Prince Cyclization of Phthalimido Arenyne Hemiaminals reaction.
#
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\d1ra01912k-2.pdf
# Which compound has the highest polymerization activity over the entire temperature range? And which one is the lowest at 80 degrees?
# There is no compound that has the highest polymerization activity. However, meso-5sMAO has the highest activity in the range of 60-90 degrees Celsius. But the lowest activity at 80 degrees is observed on 1sMAO, as in the control. If we talk about the zirconocenes, then for musso- 2 sMA.
# *   Over the entire temperature range, the compound meso-5sMAO has the highest polymerization activity.
# *   At 80 degrees, the compound meso-4sMAO has the lowest polymerization activity.
# -----------------------
# ..\ChemCoScientist\paper_analysis\papers\d1ra01912k-2.pdf
# What is rac-(3-Et Ind#)2Zr(CH2Ph)2?
# rac-(3-EtInd#)2Zr(CH2Ph)2 is a zirconocene complex, an organometallic compound consisting of a tetravalet zirconium ion [Zr-4], two 3-ethyl-2,4,5,6,7-pentamethyl-1H-inden-1-ide CCc1c(C)[cH-]c2c(C)c(C)c(C)c(C)c12 and two methanidylbenzene [CH2-]c1ccccc1
# rac-(3-Et Ind)2Zr(CH2Ph)2, is a yellow solid.  The average Zr-CH2Ph bond length is 2.303 Å. The torsion angle (TA) is 157.30°.
